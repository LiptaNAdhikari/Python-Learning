# %% [markdown]
# ## **Basic Python**

# %%
print("Hello")
print("Hi")

print("---------------")

print("Hello \nHi")

print("---------------")

print('''Hello
Hi''')
# Out:
# Hello
# Hi
# ---------------
# Hello
# Hi
# ---------------
# Hello
# Hi

# %%
a = "Hello"
print(type(a))

name = "Hi"
print(type(name))

num_1 = 10
num_2 = 10.32

print(type(num_1))
print(type(num_2))

bool_1 = True
print(bool_1 , type(bool_1))

num_3 = float(num_1)

print(num_1 , type(num_1))
print(num_3 , type(num_3))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'float'>
# True <class 'bool'>
# 10 <class 'int'>
# 10.0 <class 'float'>

# %%
print("Name : ", a,"This is number 1:", num_1)
# Out:
# Name :  Hello

# %%
print(f"Name is {a}. This is number 1: {num_1}")
# Out:
# Name is Hello. This is number 1: 10

# %%
print("My name is {} and I am {} years old.".format(a,num_1))

#This is format fucntion
# Out:
# My name is Hello and I am 10 years old.
